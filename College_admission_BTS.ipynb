# %%
#Python Program to help BTS

#Function for certification course

def certification():
    certi={"Fees": 60000 , "Duration": "8 months" , "DOb": "Anytime suitable", "Campus": "This is an online course" , "Level" : "Beginner"}
    print("\n \n \033[1m____________________________________________ABOUT CERTIFICATION COURSE_______________________________________\033[0m \n \n The certificate in the English course is designed for learning spoken and written English. It is a full-time course. \n Those students who have an interest in English and want to obtain new English skills can pursue this course.\n Focus is given only on the English language and only the English subject is taught in this certificate course. \n There is no minimum qualification required for this course.")
    print("\n What else would you like to know about the course? \n 1. Fees \n 2. Duration \n 3. Date of Commencement\n 4. Campus available \n 5. Level of course \n 6.Exit ")
    
    while True:
        try:
            i= int(input ("Enter your choice : "))
        except ValueError:
            print("Give correct input (1-6): ")
            continue
        if(i==1):
            print(certi["Fees"])
            continue
        elif(i==2):
            print(certi["Duration"])
            continue
    
        elif (i==3):
            print(certi["DOB"])
            continue             
        elif(i==4):
            print(certi["Campus"])
            continue

        elif(i==5):
            print(certi["Level"])
            continue
        elif(i==6):
            break
        else:
            print("Sorry. No such option!")
            break
            

            
#Function for Diploma in English
def diploma():                                                            #Storing nmaes of campus in tuples 
    
    dip={"Fees": 200000 , "Duration": "2 years" , "DOB": "10th Sept'21", "Campus": ("BGR","Delhi") , "Level" : "Beginner"}
    print("\n \n \033[1m____________________________________ABOUT DIPLOMA COURSE____________________________________________\033[0m \n \n This course is designed to help the candidates to learn different aspects of the English Language. \n This course aims to develop writing and reading skills and English vocabulary. \n This study builds a bridge between theory and practice of the methodology of English language. Admission process \n for this course is based on merit-list or entrance exam followed by an interview." )
    print("\n What else would you like to know about the course? \n 1. Fees \n 2. Duration \n 3. Date of Commencement \n 4. Campus available \n 5. Level of course \n 6.Exit")
    
    while True:
        try:
            i= int(input ("Enter your choice : "))
        except ValueError:
            print("Give correct input (1-6): ")
            continue
        if(i==1):
            print(dip["Fees"])
            continue
        elif(i==2):
            print(dip["Duration"])
            continue
    
        elif (i==3):
            print(dip["DOB"])
            continue             
        elif(i==4):
            print(dip["Campus"])
            continue

        elif(i==5):
            print(dip["Level"])
            continue
        elif(i==6):
            break
        else:
            print("Sorry. No such option!")
            break
        
#Function for Degree in English
def degree():
    
    deg={"Fees": 350000 , "Duration": "3 years" , "DOB": "5th Sept'21", "Campus": ("BGR","Bannerghatta"), "Level" : "Intermediate"}
    print("\n \n \033[1m __________________________________________ABOUT BA ENGLISH(H)___________Date of Commencement \n 4. Campus available \n 5. Level of course \n 6.Exit")
    
    while True:
        try:
            i= int(input ("Enter your choice : "))
        except ValueError:
            print("Give correct input (1-6): ")
            continue
        if(i==1):
            print(deg["Fees"])
            continue
        elif(i==2):
            print(deg["Duration"])
            continue
    
        elif (i==3):
            print(deg["DOE"])
            continue             
        elif(i==4):
            print(deg["Campus"])
            continue

        elif(i==5):
            print(deg["Level"])
            continue
        elif(i==6):
            break
        else:
            print("Sorry. No such option!")
            break
          
            
#function to store student information using mutable data types : LIST AND DICTIONARIES          
Dict2={}
def info():
    list1=[]
    while True:
        print("\n Enter the details for user (Press 1) or Press 2 to Exit \n")
        d=int(input("Choice: "))
        if(d==1):
            Name=input("Name: ")
            if(Name.isalpha()==True):
                try:
                    Age=int(input("Age: "))
                except:
                    print("Enter only an integer")
                    continue
                if(Age>18 and Age<41):
                    list1.append(Age)      #lISTS ARE MUTABLE
                    Email=(input("Email: "))
                    list1.append(Email)
                    Course=(input("Course? Choose one:  Degree, Diploma, Certification: "))
                    if(Course.isalpha()==True):
                            if(Course=="certificaiton" or Course=='Certification'):
                                list1.append(Course)
                                print("Thank you for the information! You have been registered into Certification Course")
                            elif(Course=="Diploma" or Course=='diploma'):
                                list1.append(Course)
                                print(" Please select campus: Pune or Delhi:  ")
                                camp=input("Campus: ")
                                if(camp.isalpha()==True):
                                    list1.append(camp)
                                    if(camp=='Pune' or camp=="pune"):
                                        print("Thank you for the information! You have been registered into Diploma course in Pune Campus")
                                    elif(camp=='Delhi' or camp=='delhi'):
                                        print("Thank you for the information! You have been registered into Diploma course in Delhi Campus")
                                    else:
                                        print("No such campus available!")
                                else:
                                    print("Enter correct campus name: ")
                        
                            elif(Course=="Degree" or Course=='degree'):
                                list1.append(Course)
                                print(" Please select campus: BGR or BGT:  ")
                                camp=input(" ")
                                if(camp.isalpha()==True):
                                    list1.append(camp)
                                    if(camp=='BGR' or camp=="bgr"):
                                        print("\n Thank you for the information! You have been registered into Degree course in Bangalore Campus")
                                    elif(camp=='BGT' or camp=='bgt'):
                                        print("\n Thank you for the information! You have been registered into Degree course in Bannerghatta Campus")
                                       
                                        Dict2.update({Name:list1}) #DICTIONARIES ARE MUTABLE
                                        print(Dict2)
   
                                    else:
                                        print("\n No such campus available")
                                else:
                                    print("\n Enter correct campus name: ")
                                    continue
                            else:
                                print("\n Please choose correct course name")
                                continue
                    else:
                        print("\n Student must be above 18 and below 40")
                        continue
            else:
                (print("Enter name using only alphabets: "))
            continue
        else:
            break
            
            
            
            
 #function to recommend courses to the student           
def recom():
    print("\n Please tell us some specifications so that we can recommend you a course?")
    fee=int(input("Fee: "))
    if(fee<55000):
        print("\n Sadly, we do not offer any courses in the given amount!")
    elif(fee>55000 and fee<=180000):
        mode=input("Mode- Campus/Online? : ")
        if(mode=='Online'):
            print("\n Based on fee, we recommend you the Online Certification Course")
        elif(mode=='Campus'):
            print("\n Sorry! We do not offer a course on campus within this fee range.\nYou can try our online certification course!")
    elif(fee<280000 and fee>180000):
        mode=input("Mode- Campus/Online? : ")
        if(mode=="Campus"):
            print("\n Based on fee, we recommend you the Diploma Course")
        else: 
            print("\n We recommend you the Online Certification Course \nYou can check it's details below!")
    else:
        mode=input("Mode- Campus/Online? : ")
        if(mode=="Campus"):
            print("\n We have two campus courses: Diploma and Degree course . Please input the maximum \n time you can dedicate to this course below so that we can give you a better suggestion!")
            time=int(input("\n What maximum time can you commit?(in years) : "))
            if(time<2):
                print("\n You need to invest more time to get a diploma/degree! Please check online certification")
            elif(time>=2 and time<3):
                print("\n You should definitely go for a Diploma Course!")
            else:
                print("\n You should definitely go for the Degree course!")
        elif(mode=="Online"):  
             print("\n We recommend you the Online Certification Course!")
        else:
             print("\n We are unable to recommend you a course. Try exploring the courses yourself!")
              
            
                
#function to help student choose course
def eng():
    print("__________________\033[1m  Welcome to Christ University : Department of English and Cultural Studies ________________________ \033[0m ")
    print(" \n The Department of English and Cultural Studies, in consonance with its mission statement,is committed to promoting an \n intellectual climate through artistic creation, critical mediation and innovative ideation. It inculcates among its \n students a critical reading of the self, the society and the imagined with the aim of moulding them into responsible \n and socially sensitive citizens. The Department facilitates their holistic development by building emotional, academic,\n social, professional and global competencies. \n  \n \n Headed by Dr. Shobana P Mathews and ably supported by a dedicated team the department continues to strive, explore \n and achieve. ")
    print(" \n \n Programs currently offered include \n 1.BA English (Hons) \n 2.Diploma in English \n 3.Online Certification Course")
    while True:
        try:
            c=int(input("\n For choosing courses you can : \n 1. Explore the courses yourself \n \n 2. Ask us for recommendation based on your specifications\n \n 3. Exit \n \n We are happy to help both ways. Please choose : "))
        except ValueError:
            print("\n \n Please enter correct choice: ")
            continue
        if(c==1):
            print(" \n 1.BA English (Hons) \n 2.Diploma in English \n 3.Online Certification Course" )
            i=int (input("\n \n Which course would you like to know about? Enter choice: "))
            choice(i)
        elif(c==2):
            recom()
        else:
            break
                    
#function to call each course function using alternative switch case               
def choice(i):
    switcher={
    1:degree,
    2:diploma,
    3:certification,
    }
    func=switcher.get(i,lambda:'Invalid course choice')
    return func()         


while True:
    print("\n \n \n ________ \033[1m WELCOME TO CHRIST UNIVERSITY ENGLISH DEPARTMENT ADMISSION HELP DESK____________\033[0m \n \n Type 1 for the English department queries \n Type 2 to finalise your course \n Type 3 to Exit")
    try:
        c=int(input("Enter choice: "))
    except ValueError:
        print("Enter correct choice")
        continue
    if(c==1):
        eng()
    elif(c==2):
        info()
    elif(c==3):
        break
    else:
        continue
# Out:
#
#
#  ________  WELCOME TO CHRIST UNIVERSITY ENGLISH DEPARTMENT ADMISSION HELP DESK____________
#
#  Type 1 for the English department queries
#  Type 2 to finalise your course
#  Type 3 to Exit
# Enter choice: 2
#
#  Enter the details for user (Press 1) or Press 2 to Exit
#
# Choice: 1
# Name: Riya
# Age: 12
#
#  Enter the details for user (Press 1) or Press 2 to Exit
#
# Choice: 1
# Name: 21edqw
# Enter name using only alphabets:
#
#  Enter the details for user (Press 1) or Press 2 to Exit

# %% [markdown]
# ###
