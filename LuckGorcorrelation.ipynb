# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('C:/Users/Dell/Downloads/d2gu.xlsx')
df2=pd.read_excel('C:/Users/Dell/Downloads/Rural Template.xlsx')
df3= pd.concat([df,df2], ignore_index=True)

# %%
df3.head()
# Out:
#    Unnamed: 0 type_respondent workplace_setup           name   age  gender  \
# 0         0.0   Self Employed             Yes    mevati devi  32.0  Female
# 1         1.0   Self Employed             Yes         Govind  45.0    Male
# 2         2.0   Self Employed             Yes          Giddi  51.0  Female
# 3         3.0   Self Employed             Yes  Shubham singh  18.0    Male
# 4         4.0   Self Employed             Yes         Anjali  18.0  Female
#
#   community          educ_qua           work_sector  \
# 0       OBC         Secondary  Currently Unemployed
# 1        SC         Secondary        Service Sector
# 2        SC         Secondary        Service Sector
# 3        SC         Secondary        Service Sector
# 4        SC  Higher Secondary              Industry
#
#                       work_sector_i  ...   id datetime s_time userid  \
# 0                            Others  ...  NaN      NaT    NaN    NaN
# ...

# %%
df3.drop(['id','lat','long','Location code','Cluster_Code','District_Code','userid', 's_time', 'datetime', 'survey_type'],axis=1)
# Out:
#       Unnamed: 0 type_respondent workplace_setup           name   age  gender  \
# 0            0.0   Self Employed             Yes    mevati devi  32.0  Female
# 1            1.0   Self Employed             Yes         Govind  45.0    Male
# 2            2.0   Self Employed             Yes          Giddi  51.0  Female
# 3            3.0   Self Employed             Yes  Shubham singh  18.0    Male
# 4            4.0   Self Employed             Yes         Anjali  18.0  Female
# ...          ...             ...             ...            ...   ...     ...
# 6459         NaN             NaN             NaN            NaN  33.0  Female
# 6460         NaN             NaN             NaN            NaN  39.0    Male
# 6461         NaN             NaN             NaN            NaN  28.0  Female
# 6462         NaN             NaN             NaN            NaN  38.0    Male
# 6463         NaN             NaN             NaN            NaN  19.0    Male
#
# ...

# %%
df2.columns
# Out:
# Index(['id', 'datetime', 's_time', 'userid', 'survey_type', 'lat', 'long',
#        'age', 'gender', 'community', 'educ_qua', 'tot_mon_income_house',
#        'tot_mon_exp_house', 'tot_cumm_save_cih_bk', 'tot_cumm_saving_jewlry',
#        'fixed_asset_land', 'fixed_asset_house', 'fixed_asset_cattle',
#        'debt_to_bank', 'debt_to_contractors', 'debt_to_money_lender',
#        'migrated_to_current_place_6_month', 'type_migration',
#        'emp_status_before_migration', 'medical facilty at work',
#        'work affecting health positive', 'rest_room_woman_workplace',
#        'problems_in_behaviour_superiors', 'problems_in_policies_management',
#        'problems_in_nonredressal_grievances', 'problems_in_others',
#        'schemes_by_govt_emp_generation', 'schemes_by_govt_household',
#        'schemes_by_govt_agri_ins', 'schemes_by_govt_health_ins',
#        'schemes_by_govt_other', 'below_poverty_line', 'health_status',
# ...

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'type_respondent', 'workplace_setup', 'name', 'age',
#        'gender', 'community', 'educ_qua', 'work_sector', 'work_sector_i',
#        'year_employment', 'workdays_weekly', 'accident_involved', 'emp_nature',
#        'wage', 'mon_inc', 'bonus', 'pf', 'wage_others', 'fringe',
#        'tot_mon_income_house', 'tot_mon_exp_house', 'tot_cumm_save_cih_bk',
#        'tot_cumm_saving_jewlry', 'tot_cumm_saving_other', 'fixed_asset_land',
#        'fixed_asset_house', 'fixed_asset_cattle', 'debt_to_bank',
#        'debt_to_contractors', 'debt_to_money_lender',
#        'migrated_to_current_place_6_month', 'type_migration',
#        'emp_status_before_migration', 'tot_emp_workplace',
#        'work affecting health positive', 'medical facilty at work',
#        'rest_room_woman_workplace', 'problems_in_behaviour_superiors',
#        'problems_in_policies_management',
#        'problems_in_nonredressal_grievances', 'problems_in_others',
# ...

# %%
obj_df= df3[['age', 'gender', 'community', 'educ_qua', 'tot_mon_income_house',
       'tot_mon_exp_house', 'tot_cumm_save_cih_bk', 'tot_cumm_saving_jewlry',
       'fixed_asset_land', 'fixed_asset_house', 'fixed_asset_cattle',
       'debt_to_bank', 'debt_to_contractors', 'debt_to_money_lender',
       'migrated_to_current_place_6_month', 'type_migration',
       'emp_status_before_migration', 'medical facilty at work',
       'work affecting health positive', 'rest_room_woman_workplace',
       'problems_in_behaviour_superiors', 'problems_in_policies_management',
       'problems_in_nonredressal_grievances', 'problems_in_others',
       'schemes_by_govt_emp_generation', 'schemes_by_govt_household',
       'schemes_by_govt_agri_ins', 'schemes_by_govt_health_ins',
       'schemes_by_govt_other', 'below_poverty_line', 'health_status',
       'treat_location', 'quality_treatment', 'Monthly Income FI', 'BPL FI',
       'Income Expenses Savings FI', 'Loan Assets FI',
       'Financial Index Negative']]

# %%
obj_df
# Out:
#        age  gender community          educ_qua  tot_mon_income_house  \
# 0     32.0  Female       OBC         Secondary                6000.0
# 1     45.0    Male        SC         Secondary                7500.0
# 2     51.0  Female        SC         Secondary                7500.0
# 3     18.0    Male        SC         Secondary                7500.0
# 4     18.0  Female        SC  Higher Secondary                7500.0
# ...    ...     ...       ...               ...                   ...
# 6459  33.0  Female        SC           Primary               19000.0
# 6460  39.0    Male       OBC           Primary                5500.0
# 6461  28.0  Female       OBC           Primary                5000.0
# 6462  38.0    Male        SC           Primary                6000.0
# 6463  19.0    Male        SC           Primary                5000.0
#
#       tot_mon_exp_house  tot_cumm_save_cih_bk  tot_cumm_saving_jewlry  \
# ...

# %%
obj_df
# Out:
#        age  gender community          educ_qua  tot_mon_income_house  \
# 0     32.0  Female       OBC         Secondary                6000.0
# 1     45.0    Male        SC         Secondary                7500.0
# 2     51.0  Female        SC         Secondary                7500.0
# 3     18.0    Male        SC         Secondary                7500.0
# 4     18.0  Female        SC  Higher Secondary                7500.0
# ...    ...     ...       ...               ...                   ...
# 6459  33.0  Female        SC           Primary               19000.0
# 6460  39.0    Male       OBC           Primary                5500.0
# 6461  28.0  Female       OBC           Primary                5000.0
# 6462  38.0    Male        SC           Primary                6000.0
# 6463  19.0    Male        SC           Primary                5000.0
#
#       tot_mon_exp_house  tot_cumm_save_cih_bk  tot_cumm_saving_jewlry  \
# ...

# %%
[['age', 'gender', 'community', 'educ_qua', 'tot_mon_income_house',
       'tot_mon_exp_house', 'tot_cumm_save_cih_bk', 'tot_cumm_saving_jewlry',
       'fixed_asset_land', 'fixed_asset_house', 'fixed_asset_cattle',
       'debt_to_bank', 'debt_to_contractors', 'debt_to_money_lender',
       'migrated_to_current_place_6_month', 'type_migration',
       'emp_status_before_migration', 'medical facilty at work',
       'work affecting health positive', 'rest_room_woman_workplace',
       'problems_in_behaviour_superiors', 'problems_in_policies_management',
       'problems_in_nonredressal_grievances', 'problems_in_others',
       'schemes_by_govt_emp_generation', 'schemes_by_govt_household',
       'schemes_by_govt_agri_ins', 'schemes_by_govt_health_ins',
       'schemes_by_govt_other', 'below_poverty_line', 'health_status',
       'treat_location', 'quality_treatment', 'Monthly Income FI', 'BPL FI',
       'Income Expenses Savings FI', 'Loan Assets FI',
       'Financial Index Negative']]
# Out:
# [['age',
#   'gender',
#   'community',
#   'educ_qua',
#   'tot_mon_income_house',
#   'tot_mon_exp_house',
#   'tot_cumm_save_cih_bk',
#   'tot_cumm_saving_jewlry',
#   'fixed_asset_land',
#   'fixed_asset_house',
#   'fixed_asset_cattle',
#   'debt_to_bank',
#   'debt_to_contractors',
#   'debt_to_money_lender',
#   'migrated_to_current_place_6_month',
#   'type_migration',
#   'emp_status_before_migration',
#   'medical facilty at work',
#   'work affecting health positive',
#   'rest_room_woman_workplace',
#   'problems_in_behaviour_superiors',
#   'problems_in_policies_management',
#   'problems_in_nonredressal_grievances',
#   'problems_in_others',
#   'schemes_by_govt_emp_generation',
#   'schemes_by_govt_household',
#   'schemes_by_govt_agri_ins',
#   'schemes_by_govt_health_ins',
#   'schemes_by_govt_other',
#   'below_poverty_line',
#   'health_status',
#   'treat_location',
#   'quality_treatment',
#   'Monthly Income FI',
#   'BPL FI',
#   'Income Expenses Savings FI',
# ...

# %%
obj_df["Monthly Income FI"] = obj_df["Monthly Income FI"].map( 
                   {'Y':1 ,'N':0})
obj_df["BPL FI"] = obj_df["BPL FI"].map( 
                   {'Y':1 ,'N':0})
obj_df["Income Expenses Savings FI"] = obj_df["Income Expenses Savings FI"].map( 
                   {'Y':1 ,'N':0})

obj_df["Loan Assets FI"] = obj_df["Loan Assets FI"].map( 
                   {'Y': 1 ,'N':0})

obj_df["Financial Index Negative"] = obj_df["Financial Index Negative"].map( 
                   {'Y':1 ,'N':0})

obj_df["medical facilty at work"] = obj_df["medical facilty at work"].map( 
                   {'Yes':1 ,'No':0})
obj_df["work affecting health positive"] = obj_df["work affecting health positive"].map( 
                   {'Yes':1 ,'No':0})
obj_df["fixed_asset_land"] = obj_df["fixed_asset_land"].map( 
                   {'Yes':1 ,'No':0})
obj_df["fixed_asset_cattle"] = obj_df["fixed_asset_cattle"].map( 
                   {'Yes':1 ,'No':0})
obj_df["gender"] = obj_df["gender"].map( 
                   {'Female':1 ,'Male':0})
obj_df["fixed_asset_house"] = obj_df["fixed_asset_house"].map( 
                   {'Yes':1 ,'No':0})
obj_df["community"] = obj_df["community"].map( 
                   {'OBC':2 ,'SC':1, 'ST':0, 'FC':3})
obj_df["educ_qua"] = obj_df["educ_qua"].map( 
                   {'Graduate & Above':3 ,'Secondary':2, 'Primary':0, 'Higher Secondary':1, })
obj_df["work_sector"] = obj_df["work_sector"].map( 
                   {'Currently Unemployed':3 ,'Service Sector':2, 'Industry':0, 'Agriculture':1, 'Mining': 4, "Doesn't want to answer":5, 'Households': 6})
# Out:
# <ipython-input-170-b05e15d17f62>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj_df["Monthly Income FI"] = obj_df["Monthly Income FI"].map(
# <ipython-input-170-b05e15d17f62>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj_df["BPL FI"] = obj_df["BPL FI"].map(
# <ipython-input-170-b05e15d17f62>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
obj_df["debt_to_bank"] = obj_df["debt_to_bank"].map( 
                   {"Yes":1 ,"No":0})
obj_df["debt_to_contractors"] = obj_df["debt_to_contractors"].map( 
                   {"Yes":1 ,"No":0})
obj_df["debt_to_money_lender"] = obj_df["debt_to_money_lender"].map( 
                   {"Yes":1 ,"No":0})
obj_df["migrated_to_current_place_6_month"] = obj_df["migrated_to_current_place_6_month"].map( 
                   {"Yes":1 ,"No":0})
obj_df["rest_room_woman_workplace"] = obj_df["rest_room_woman_workplace"].map( 
                   {"Yes":1 ,"No":0})
obj_df["problems_in_behaviour_superiors"] = obj_df["problems_in_behaviour_superiors"].map( 
                   {"Yes":1 ,"No":0})
obj_df["problems_in_policies_management"] = obj_df["problems_in_policies_management"].map( 
                   {"Yes":1 ,"No":0})
obj_df["problems_in_nonredressal_grievances"] = obj_df["problems_in_nonredressal_grievances"].map( 
                   {"Yes":1 ,"No":0})
obj_df["problems_in_others"] = obj_df["problems_in_others"].map( 
                   {"Yes":1 ,"No":0})
obj_df["schemes_by_govt_emp_generation"] = obj_df["schemes_by_govt_emp_generation"].map( 
                   {"Yes":1 ,"No":0})

obj_df["schemes_by_govt_household"] = obj_df["schemes_by_govt_household"].map( 
                   {"Yes":1 ,"No":0})

obj_df["schemes_by_govt_agri_ins"] = obj_df["schemes_by_govt_agri_ins"].map( 
                   {"Yes":1 ,"No":0})

obj_df["schemes_by_govt_health_ins"] = obj_df["schemes_by_govt_health_ins"].map( 
                   {"Yes":1 ,"No":0})

obj_df["schemes_by_govt_other"] = obj_df["schemes_by_govt_other"].map( 
                   {"Yes":1 ,"No":0})

obj_df["below_poverty_line"] = obj_df["below_poverty_line"].map( 
                   {"Yes":1 ,"No":0, "Doesn't want to answer" : 2})

obj_df["health_status"] = obj_df["health_status"].map( 
                   {'Good':4 ,'Average':3, 'Very Poor':1, 'Poor': 2, "Doesn't want to answer":0, 'Excellent': 5})

obj_df["quality_treatment"] = obj_df["quality_treatment"].map( 
                   {'Good':4 ,'Average':3, 'Very Poor':1, 'Poor': 2, "Doesn't want to answer":0, 'Excellent': 5})
# Out:
# <ipython-input-171-c703da7d3fb7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj_df["debt_to_bank"] = obj_df["debt_to_bank"].map(
# <ipython-input-171-c703da7d3fb7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj_df["debt_to_contractors"] = obj_df["debt_to_contractors"].map(
# <ipython-input-171-c703da7d3fb7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
obj_df
# Out:
#        age  gender  community  educ_qua  tot_mon_income_house  \
# 0     32.0     1.0        2.0       2.0                6000.0
# 1     45.0     0.0        1.0       2.0                7500.0
# 2     51.0     1.0        1.0       2.0                7500.0
# 3     18.0     0.0        1.0       2.0                7500.0
# 4     18.0     1.0        1.0       1.0                7500.0
# ...    ...     ...        ...       ...                   ...
# 6459  33.0     1.0        1.0       0.0               19000.0
# 6460  39.0     0.0        2.0       0.0                5500.0
# 6461  28.0     1.0        2.0       0.0                5000.0
# 6462  38.0     0.0        1.0       0.0                6000.0
# 6463  19.0     0.0        1.0       0.0                5000.0
#
#       tot_mon_exp_house  tot_cumm_save_cih_bk  tot_cumm_saving_jewlry  \
# 0                3000.0                3000.0                     NaN
# 1                6600.0                 900.0                     NaN
# ...

# %%
obj_df["treat_location"] = obj_df["treat_location"].map( 
                   {'Private':3, 'Government':1, 'Self': 2, "Doesn't want to answer":0})
# Out:
# <ipython-input-173-7ec6da47f3b6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj_df["treat_location"] = obj_df["treat_location"].map(

# %%
obj_df["emp_status_before_migration"] = obj_df["emp_status_before_migration"].map( 
                   { 'Unemployed':1, 'Employed': 2, "Doesn't want to answer":0})
# Out:
# <ipython-input-174-6ccfba19a255>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj_df["emp_status_before_migration"] = obj_df["emp_status_before_migration"].map(

# %%
obj_df["type_migration"] = obj_df["type_migration"].map( 
                   { 'With Family Members':1, 'As Individual': 2, "Doesn't want to answer":0})
# Out:
# <ipython-input-175-9b29293a0b81>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   obj_df["type_migration"] = obj_df["type_migration"].map(

# %%
obj_df
# Out:
#        age  gender  community  educ_qua  tot_mon_income_house  \
# 0     32.0     1.0        2.0       2.0                6000.0
# 1     45.0     0.0        1.0       2.0                7500.0
# 2     51.0     1.0        1.0       2.0                7500.0
# 3     18.0     0.0        1.0       2.0                7500.0
# 4     18.0     1.0        1.0       1.0                7500.0
# ...    ...     ...        ...       ...                   ...
# 6459  33.0     1.0        1.0       0.0               19000.0
# 6460  39.0     0.0        2.0       0.0                5500.0
# 6461  28.0     1.0        2.0       0.0                5000.0
# 6462  38.0     0.0        1.0       0.0                6000.0
# 6463  19.0     0.0        1.0       0.0                5000.0
#
#       tot_mon_exp_house  tot_cumm_save_cih_bk  tot_cumm_saving_jewlry  \
# 0                3000.0                3000.0                     NaN
# 1                6600.0                 900.0                     NaN
# ...

# %%
obj_df.corr()
# Out:
#                                           age    gender  community  educ_qua  \
# age                                  1.000000 -0.023217   0.018166 -0.094133
# gender                              -0.023217  1.000000  -0.009563  0.016995
# community                            0.018166 -0.009563   1.000000  0.073715
# educ_qua                            -0.094133  0.016995   0.073715  1.000000
# tot_mon_income_house                -0.020488  0.019316   0.009835  0.022646
# tot_mon_exp_house                   -0.020978  0.019865   0.010223  0.024097
# tot_cumm_save_cih_bk                 0.009439 -0.024993   0.031074 -0.035562
# tot_cumm_saving_jewlry               0.135986 -0.062477   0.238580  0.119711
# fixed_asset_land                    -0.028187  0.032890   0.076574  0.088350
# fixed_asset_house                   -0.001549  0.021984  -0.046380 -0.005592
# fixed_asset_cattle                  -0.009961 -0.010505   0.086910 -0.020709
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(4,10))
sns.heatmap(obj_df.corr()[['Financial Index Negative']].sort_values(by=['Financial Index Negative'],ascending=False),cmap='mako',annot=True)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(obj_df.corr(), cmap= 'coolwarm')
