# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
link = "https://www.amazon.in/SPACES-Breatheable-Bedsheet-274CMX274CM-43CMX68CM/dp/B096KHS9T3"

# %%
page= requests.get(link)

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41jsiPzxYxL.css,31qGOnSAToL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.css,11bGSgD5pDL.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,21N4kUH7pxL.css,01oDR3IULNL.css,41-PwE7+H0L.css,21j0IlW7xKL.css,01XPHJk60-L.css,116uEeuY3+L.css,21aPhFy+riL.css,11gneA3MtJL.css,21fecG8pUzL.css,01ulGzBW88L.css,01CFUgsA
# ...

# %%
soup=bs(page.content,features='lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:feature:aui-assets -->
# ...

# %%
details=(soup.find_all('th', class_="a-color-secondary a-size-base prodDetSectionEntry"))

# %%
detail_name=[]
for i in range(0,len(details)):
    detail_name.append(details[i].get_text().strip())

# %%
print(detail_name)
# Out:
# ['Color', 'Product Dimensions', 'Shipping Weight', 'Item Model Number', 'Item Part Number', 'Primary material', 'Upholstery material', 'Capacity', 'Weight', 'Manufacturer', 'Country of Origin', 'ASIN', 'Customer Reviews', 'Best Sellers Rank', 'Date First Available', 'Manufacturer', 'Packer', 'Item Weight', 'Item Dimensions LxWxH', 'Generic Name']

# %%
detail_final=[]
for i in range(len(detail_name)):
    if(detail_name[i]=='Customer Reviews' or detail_name[i]=='Best Sellers Rank' or detail_name[i]=='Item Weight'):
        detail_final.append(detail_name[i])
        i+=1

# %%
detail_final
# Out:
# ['Customer Reviews', 'Best Sellers Rank', 'Item Weight']

# %%
detail_v1=soup.find_all('td')

# %%
cust=[]
for i in range(0,len(detail_v1)):
        cust.append(detail_v1[i].get_text().strip().strip(u'\u200e'))

# %%
print(cust)
# Out:
# ['M.R.P.:', '₹3,599.00', 'Price:', '₹1,799.00', 'You Save:', '₹1,800.00 (50%)', '', 'Inclusive of all taxes', 'Size', 'King', 'Material', 'Cotton', 'Colour', 'Cream', 'Pattern', 'Ornate', 'Thread Count', '144', 'Brand', 'Spaces', 'Product Care Instructions', 'Dry Clean Only', 'Are you a business? Get GST invoice and bulk discountsSign in/Create a free business account', 'Cream', '274 x 274 x 1 cm; 1.4 Kilograms', '1.28 Kilograms', '1052095', '1052095', 'Cotton', 'Cotton', 'King', '1400 Grams', 'Welspun Global Brands Limited', 'India', 'B096KHS9T3', '3.0 out of 5 stars\n\n\n\n\n\n\n\n\n3 ratings\n\n\n\n\n\n\n3.0 out of 5 stars', '#17,229 in Home & Kitchen (See Top 100 in Home & Kitchen)\n\n#423 in Flat Bed Sheets', '3 June 2021', 'Welspun Global Brands Limited, Welspun City,Village Versamedi,Tal. Anjar,District Kutch', 'WELSPUN GLOBAL BRANDS LTD., Welspun House, 6th Floor, Kamala City, Senapati Bapat Marg, Lower Parel (W), Mumbai-400 013, Maharashtra, India', '1 kg 400 g', '2.74 x 2.7
# ...

# %%
detail_value

# %%
detailzz=(soup.find_all('tr'))

# %%
detailzz
# Out:
# [<tr>
#  <td class="a-color-secondary a-size-base a-text-right a-nowrap">M.R.P.:</td>
#  <td class="a-span12 a-color-secondary a-size-base">
#  <span class="priceBlockStrikePriceString a-text-strike"> ₹3,599.00</span>
#  <span id="listPriceLegalMessage">
#  </span>
#  <style>
#  #listPriceLegalMessageText {
#  margin-left: 5px !important;
#  }
#  #listPriceLegalMessage .a-popover-trigger:hover {
#  text-decoration: underline !important;
#  }
#  #listPriceLegalMessage .a-icon-popover {
#  display: inline-block !important;
#  margin-left: 0px !important;
#  margin-top: 6px !important;
#  }
#  </style>
#  </td>
#  </tr>,
#  <tr id="priceblock_ourprice_row">
#  <td class="a-color-secondary a-size-base a-text-right a-nowrap" id="priceblock_ourprice_lbl">Price:</td>
#  <td class="a-span12">
#  <span class="a-size-medium a-color-price priceBlockBuyingPriceString" id="priceblock_ourprice">₹1,799.00</span>
#  <!--this file can be removed once there is no reference in code search:
# ...

# %%
final=[]
for i in range(0,len(detailzz)):
        final.append(detailzz[i].get_text().strip().strip(u'\u200e'))

# %%
print(final)
# Out:
# ['M.R.P.:\n\n ₹3,599.00', 'Price:\n\n₹1,799.00', 'You Save:\n\n\n\n\n₹1,800.00 (50%)', 'Inclusive of all taxes', 'Size\n\n\nKing', 'Material\n\n\nCotton', 'Colour\n\n\nCream', 'Pattern\n\n\nOrnate', 'Thread Count\n\n\n144', 'Brand\n\n\nSpaces', 'Product Care Instructions\n\n\nDry Clean Only', 'Are you a business? Get GST invoice and bulk discountsSign in/Create a free business account', 'Color\n\n\n\u200eCream', 'Product Dimensions\n\n\n\u200e274 x 274 x 1 cm; 1.4 Kilograms', 'Shipping Weight\n\n\n\u200e1.28 Kilograms', 'Item Model Number\n\n\n\u200e1052095', 'Item Part Number\n\n\n\u200e1052095', 'Primary material\n\n\n\u200eCotton', 'Upholstery material\n\n\n\u200eCotton', 'Capacity\n\n\n\u200eKing', 'Weight \n\n\n\u200e1400 Grams', 'Manufacturer\n\n\n\u200eWelspun Global Brands Limited', 'Country of Origin\n\n\n\u200eIndia', 'ASIN\n\n\nB096KHS9T3', 'Customer Reviews\n\n\n\n\n\n\n\n3.0 out of 5 stars\n\n\n\n\n\n\n\n\n3 ratings\n\n\n\n\n\n\n3.0 out of 5 stars', 'Best Sellers Rank\n\
# ...

# %%
ratingz=(soup.find('i', class_='a-icon a-icon-star a-star-3'))

# %%
print(ratingz.get_text())
# Out:
# 3.0 out of 5 stars

# %%
ratingz.text
