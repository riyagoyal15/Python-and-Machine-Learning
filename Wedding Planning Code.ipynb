# %%
# Python Program to take care of the budget for the entire marriage ceremony of Salman Khan.

# %%
#user defined function for finalising tickets

def ticks(x):
    print(" \n \n \033[1m_____Welcome to Ticket selection Portal_____\033[0m")
    if(x=="Dubai"):
        print("\n \n We have the following options for your travel to", x, ": \n \n 1.Business class - ₹85000 \n 2.Economy class - ₹52000 \n \n Choose the desired option: (1/2) :")
        while True:
            try:
                n=int(input("\nEnter choice: ")) #validations
            except ValueError:
                print(" Input only numbers (1/2)")
                continue
            if(n==1):
                print("How many tickets would you like to book?") 
                y = int(input())
                tikprice = lambda y: y *85000  #lambda function to calculate final ticket price
            elif(n==2):
                print("How many tickets would you like to book?")
                y = int(input())
                tikprice = lambda y:  y *52000
                break
            else:
                print("Choose right option!")
                continue
                
        ticks.tick=tikprice(y)
        
    elif(x=="Malaysia"):
        print("\n \n We have the following options for your travel to", x, ": \n \n 1.Business class - ₹65000 \n 2.Economy class - ₹46000 \n \n Choose the desired option: (1/2) :")
        
        while True:
            try:
                n=int(input("\nEnter choice: "))
            except ValueError:
                print(" Input only numbers (1/2)")  #Validations
                continue
            if(n==1):
                print("How many tickets would you like to book?") 
                y = int(input())
                tikprice = lambda y: y *65000
                break
            elif(n==2):
                print("How many tickets would you like to book?")
                y = int(input())
                tikprice = lambda y:  y *46000
                break
            else:
                print("Choose right option!")
                continue
                
        ticks.tick=tikprice(y)
    elif(x=="Bali"):
        print("\n \n We have the following options for your travel to", x, ": \n \n 1.Business class - ₹67000 \n 2.Economy class - ₹44000 \n \n Choose the desired option: (1/2) :")
        while True:
            try:
                n=int(input("\nEnter choice: "))
            except ValueError:
                print(" Input only numbers (1/2)")
                continue
            if(n==1):
                print("How many tickets would you like to book?") 
                y = int(input())
                tikprice = lambda y: y *67000
                break
            elif(n==2):
                print("How many tickets would you like to book?")
                y = int(input())
                tikprice = lambda y:  y *44000
                break
            else:
                print("Choose right option!")
                continue
        ticks.tick=tikprice(y)
    print("Your total ticket cost would be : ", ticks.tick)
    print("Now that you have calculated the ticket price, let's head on to calculating your final budget\n after conversion of currency and addition of ticket amount to Venue cost\n \n ")
    conv(dest.venue) #calling the conversion function                                                                                                                                                                                                                                            
    

#function to finalise destination

def dest():
    
    print(" \n \n \033[1m__________Welcome to the Destination selection portal________________\033[0m")
    print("\n \n We have shortlisted the following options for your 4 day destination Wedding according to the budget we discussed: \n \n 1.Paradise Resort,Bali \n 2.Pearl Jumeirah, Malaysia \n 3.The Ritz-Carlton,Dubai \n 4.Exit \n \n Choose the desired option: (1/2/3/4) :")
    while True:
        try:
            n=int(input("\nEnter choice: "))
        except ValueError:
            print(" Input only numbers (1/2/3/4)") #validations
            continue
        if(n==1):
            print("\n \n Thank you for selecting Bali as your Destination Wedding place. \n \n World famous Hyatt Regency has its magnificent 5-star hotel in Dubai, which has hosted around 5000 weddings \n till now. Housing a vast and charismatic Crystal Ballroom, an elegant Outdoor Golf Park, and a specialized culinary \n team, Hyatt Regency offers a once in a lifetime wedding experience in Dubai. \n \n Location: SandArena, Bali \n \n  Seating capacity: Upto 1000 guests\n \n Cost:9145690000 Indonesian Rupiah")  
            dest.venue="Bali"
            dest.p= 9145690000
            break
        elif(n==2):
            print("\n \n Thank you for selecting Malaysia as your Destination Wedding place. \n \n Favourably located on the beachfront, overlooking the astounding Pearl Jumeirah is a picturesque\n destination to have that utopian wedding. Offering an array of luxury amenities amidst its paradisiacal surroundings,\n this wedding destination is ideal to have your dream wedding in Dubai. Tendering to the exclusive needs of its guests,\n this resort offers access to a private patio, private rooftop pool, deluxe villas and so much more. \n \n Location: Pearl Jumeira, Malaysia. \n \n Seating capacity: Upto 900 guests \n \n Cost: 2568000 Malaysian Ringgit") 
            dest.venue="Malaysia"
            dest.p= 2568000
            break
        elif(n==3):
            print("\n \n Thank you for selecting Dubai as your Destination Wedding place. \n \n Considered to be one of the affordable wedding venues in Dubai, The Ritz-Carlton is one of the best wedding venues in Dubai \n and has great value for money. What is even more impressive is that the beach facing awning, the blooming landscape,\n the lush lawns and the traditional decor give an elegant setting for any type of wedding. Their services are impeccable, \n as they make sure they take of all your requirements including your budget!\n \n Location: Dubai, 26525 United Arab Emirates \n \n Seating Capacity: 800-1000 guests\n Cost: 2265800 AED")
            dest.venue="Dubai"
            dest.p=2265800
            break
        elif(n==4):
            break    
        else:
            print("Choose right option!")
            continue
            
    if(n==4):
        exit()  #using in-built function to exit
    else:
        print("\n \n I hope you don't ignore the currencies here! They are all under your budget, don't worry. \n If this suits your specifications, would you like to continue with this destination?")
        while True:
            ch2= input("(Y / N) : ")
            if(ch2.isalpha() ==True): #using inbuilt function
                if(ch2=='Y' or ch2=='y'):
                    print("\n Great! Let's head on to finalising your ticket prices.")
                    if(n==1):
                        ticks("Bali")
                    elif(n==2):
                        ticks("Malaysia")
                    elif(n==3):
                        ticks("Dubai")
                    break
                elif(ch2=='N' or ch2=='n'):
                    print("\n Sure. You can try choosing the other destination.")
                    dest()  #recursive function, calling itself again
                    break
                else:
                    print("Give the correct input (Y/N)")
                    continue
            else:
                print("Give the correct input (Y/N)")
                continue

                
                
#function to convert the currency
def conv(x):
    
    print(" \n \n \033[1m__________Welcome to the Conversion portal________________\033[0m \n \n Would you like to convert you currency? ( y/n ): ")
    while True:
        ch2= input("(Y / N) : ")
        if(ch2.isalpha() ==True): #using inbuilt function for validation
            if(ch2=='Y' or ch2=='y'):
                print("\n Great!")
                break
            elif(ch2=='N' or ch2=='n'):
                print("\n Sure. You can go back to the Destination Menu")
                dest() 
                break
            else:
                print("Give the correct input (Y/N)")
                continue
        else:
            print("Give the correct input (Y/N)")
            continue
    if(x=='Dubai'):
        conv.p= lambda l:l*19.895
        print("\n So your current price is in AED. Here's your INR amount after conversion: Rs.", conv.p(dest.p))
    elif(x=="Malaysia"):
        conv.p= lambda l:l*17.6177
        print("\n So your current price is in AED. Here's your INR amount after conversion: Rs.", conv.p(dest.p))
    elif(x=="Bali"):
        conv.p= lambda l:l*0.0051
        print("\n So your current price is in AED. Here's your INR amount after conversion: Rs.", conv.p(dest.p))
    m=conv.p((dest.p))    
    print("Let us now calculate your total amount after adding: \nTicket price, Venue price and Tax. \n \n Would you like to continue?")
    while True:
        ch= input("(Y / N) : ")
        if(ch2.isalpha() ==True): #using inbuilt function
            if(ch=='Y' or ch=='y'):
                print("\n Great!")
                break
            elif(ch=='N' or ch=='n'):
                print("\n Sure. You can go back to the Destination Menu")
                dest() 
                break
            else:
                print("Give the correct input (Y/N)")
                continue
        else:
            print("Give the correct input (Y/N)")
            continue
    
    tprice= lambda a,b: a+b+b*0.18     #using lambda function to calculate final amount
    
    print(" \n \n Total Amount to be paid is : ", tprice(ticks.tick,m), " which includes: \n 1.Venue Amount: Rs.", m , "\n 2.Ticket Price: Rs.", ticks.tick, "\n 3.Tax price: Rs.", m*0.18)
    print("\n \n  It was great helping you choose options for your destination Wedding Mr. Khan! \n \n  The final amount is an approximate. \n Since you are our special customer, we would love to offer you a discount \n regarding which we can have a discussion later! Hope you have a good day!!")
        

        
        
print("\n \n \033[1m__________________Welcome to Made in Heaven______________________ \033[0m \n \n Thank you choosing us Mr. Khan ! We are here for your Service")
print("\n Let's start planning your entire wedding your way!\n To move ahead, we would first have to finalize your wedding destination! Are you ready? \n ")
while True:
    ch1= input("(Y / N) : ")
    if(ch1.isalpha() ==True): #using inbuilt function
        if(ch1=='Y' or ch1=='y'):
            print("Great! \n \n ")
            dest()
            
            break
        elif(ch1=='N' or ch1=='n'):
            print("Sure. You can come back later")
            break
        else:
            print("Give the correct input (Y/N)")
            continue
# Out:
#
#  __________________Welcome to Made in Heaven______________________
#
#  Thank you choosing us Mr. Khan ! We are here for your Service
#
#  Let's start planning your entire wedding your way!
#  To move ahead, we would first have to finalize your wedding destination! Are you ready?
#
# (Y / N) : Y
# Great!
#
#
#
#
#  __________Welcome to the Destination selection portal________________
#
#
#  We have shortlisted the following options for your 4 day destination Wedding according to the budget we discussed:
#
#  1.Paradise Resort,Bali
#  2.Pearl Jumeirah, Malaysia
#  3.The Ritz-Carlton,Dubai
#  4.Exit
#
#  Choose the desired option: (1/2/3/4) :
#
# Enter choice: 2
#
#
#  Thank you for selecting Malaysia as your Destination Wedding place.
#
#  Favourably located on the beachfront, overlooking the astounding Pearl Jumeirah is a picturesque
#  destination to have that utopian wedding. Offering an array of luxury amenities amidst its paradisiacal surroundings,
# ...
