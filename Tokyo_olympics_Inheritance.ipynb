# %%
import numpy as np  #importing numpy

class TokyoG(): #defining class TokyoG for Tokyo Games
    def __init__(self, t): #defining init function of the class TokyoG
        self.tot=t
        print("\n Total number of participants in Tokyo Olympics 2020 as of now are: {}".format (self.tot))   
    def country(self, list1):
        self.l1=list1
        #converting list into a numpy array
        x=np.array(self.l1)
        #using unique to get unique names fomr the country name list
        print(" The list of countries participating in Tokyo Olympics 2020 as of now are : {}". format(np.unique(x)))
        
        
#defining class TokyoP for Tokyo Paralympic Games

class TokyoP():
    #defining init function of the class TokyoG
    def __init__(self, l):
        self.tol=l
        print("\n Total number of participants in Tokyo Paralympics 2020 as of now are: {}".format (self.tol))        
    def country(self, list2):
        self.l2=list2
        #converting list into a numpy array
        y=np.array(self.l2)
        #using unique to get unique names fomr the country name list
        print(" The list of countries participating in Tokyo Paralympics 2020 as of now are : {}". format(np.unique(y)))
        

        
#inheriting class Event from Parent classes TokyoG anf TokyoP
#Displaying multiple inheritance

class Event(TokyoG,TokyoP):
    
    sevent= " "
    scountry1= " "
    scountry2= " "
    l1=[]
    l2=[]
    sparticipant= 0
    totpart= 0
    totpart2=0
    sdate=" 17-Mar-2020"
    
    def __init__(self):
        print("\n \n Welcome to Events of Tokyo 2020 ")
        TokyoG.__init__(self,self.totpart) #calling function from parent class TokyoG
        TokyoP.__init__(self,self.totpart2) #calling function from parent class TokyoP
        TokyoG.country(self,self.l1)
        TokyoP.country(self,self.l2)
        
    def deets(self):
        print( "\n \nThank you for registering in this event. \nThe details are as follows: \n")
        print("{} has successfully registered for {} with {} number of participants on {}".format(self.scountryname,self.sevent,self.sparticipant,self.sdate))
    
    

#inheriting class SWimming from class Event
#displaying hierarchical inheritance

class Swimming(Event):
    Event.sevent= "Swimming"  #storing value in parent class attribute
    def __init__(self,c="Olympics"):
        Event.sdate= "19-Mar-2020" #storing value in parent class attribute
        self.h=c
        if(self.h=="Olympics" or self.h=="Paralympics"): #validations
            print("\n Your event {} is on {}.To register for {}, ". format (Event.sevent,Event.sdate, self.h))
            while True:
                print("\n Please enter your country name: ")
                self.c=input(" ")
                if(self.c.isalpha()==True):
                    if(self.h=="Olympics"):
                        Event.scountry1=self.c   #storing value in parent class attribute
                        Event.l1.append(Event.scountry1) 
                    elif(self.h=="Paralympics"):
                        Event.scountry2=self.c   #storing value in parent class attribute
                        Event.l2.append(Event.scountry2)  
                    self.number()
                    break
                else:
                    print("Enter only alphabets")
                    continue
        else:
            print("\n Enter correct category (Olympics/Paralympics)") #validations
            
        
    def number(self): 
        print("\n Enter the number of participants from your country (0-4)")
        while True:   #validating input based on number of participants allowed
            try:
                self.n=int(input(" "))
            except ValueError:
                print("\n Enter only a number between 0-4")
                continue
            if(self.n<0 or self.n>4):
                print("\n Enter only between 0-4")
                continue
            else:
                Event.sparticipant=self.n
                if(self.h=="Olympics"):
                    Event.totpart=Event.totpart+self.n  #changing value of Parent class attribute
                else:
                    Event.totpart2=Event.totpart2+self.n
                break
            
        
        Event.__init__(self)  #calling the parent class function to display details 

#inheriting class Javelin from class Event
#displaying hierarchical inheritance


class Javelin(Event):
    Event.sevent= "Javelin" #storing value in parent class attribute
    def __init__(self,c="Olympics"):
        Event.sdate= "20-Mar-2020"  #storing value in parent class attribute
        self.h=c
        if(self.h=="Olympics" or self.h=="Paralympics"):   #validations
            print("\n Your event {} is on {}.To register for {}, ". format (Event.sevent,Event.sdate, self.h))
            while True:
                print("\n Please enter your country name: ")
                self.c=input(" ")
                if(self.c.isalpha()==True):
                    if(self.h=="Olympics"):
                        Event.scountry1=self.c   #storing value in parent class attribute
                        Event.l1.append(Event.scountry1) 
                    elif(self.h=="Paralympics"):
                        Event.scountry2=self.c   #storing value in parent class attribute
                        Event.l2.append(Event.scountry2)  
                    self.number()
                    break
                else:
                    print("Enter only alphabets")
                    continue
        else:
            print("\n Enter correct category (Olympics/Paralympics)")  #validations
            
    def number(self):
        print("\n Enter the number of participants from your country (0-2)")
        while True:  #validating input based on number of participants allowed
            try:
                self.n=int(input(" "))
            except ValueError:
                print("\n Enter only a number between 0-2")
                continue
            if(self.n<0 or self.n>2):
                print("\n Enter only between 0-2")
                continue
            else:
                Event.sparticipant=self.n
                if(self.h=="Olympics"):
                    Event.totpart=Event.totpart+self.n  #changing value of Parent class attribute
                else:
                    Event.totpart2=Event.totpart2+self.n #changing value of Parent class attribute
                break
            
        
        Event.__init__(self)  #calling the parent class function to display details 
    
    
class HighJump(Event):
    Event.sevent= "High Jump"  #storing value in parent class attribute
    def __init__(self,c="Olympics"):
        Event.sdate= "21-Mar-2020"  #storing value in parent class attribute
        self.h=c
        if(self.h=="Olympics" or self.h=="Paralympics"): #validations
            print("\n Your event {} is on {}.To register for {}, ". format (Event.sevent,Event.sdate, self.h))
            while True:
                print("\n Please enter your country name: ")
                self.c=input(" ")
                if(self.c.isalpha()==True):
                    if(self.h=="Olympics"):
                        Event.scountry1=self.c   #storing value in parent class attribute
                        Event.l1.append(Event.scountry1) 
                    elif(self.h=="Paralympics"):
                        Event.scountry2=self.c   #storing value in parent class attribute
                        Event.l2.append(Event.scountry2)  
                    self.number()
                    break
                else:
                    print("Enter only alphabets")
                    continue
        else:
            print("\n Enter correct category (Olympics/Paralympics)") #validations
            
    def number(self):
        print("\n Enter the number of participants from your country (0-3)")
        while True:  #validating input based on number of participants allowed
            try:
                self.n=int(input(" "))
            except ValueError:
                print("Enter only a number between 0-3")
                continue
            if(self.n<0 or self.n>3):
                print("Enter only between 0-3")
                continue
            else:
                Event.sparticipant=self.n
                if(self.h=="Olympics"):
                    Event.totpart=Event.totpart+self.n  #changing value of Parent class attribute
                else:
                    Event.totpart2=Event.totpart2+self.n #changing value of Parent class attribute
                break
            
        
        Event.__init__(self)  #calling the parent class function to display details 
        
        
        
print(" _______________________THE HISTORY OF OLYMPICS_________________________ \n \n ")
print("The roots of today’s Olympic Games date back to the ancient Olympic Games,\nheld 2,800 years ago. Also known as the '''Olympiad''' the event\ntook place in the Olympia region of ancient Greece. There are various\npinions regarding its origins. It is said that the event was an athletic\nand artistic festival dedicated to the worship of the gods.\nBut the ancient Olympic Games were hindered by numerous conflicts and finally\ncame to an end in 393 AD.")

print (" ________________________MODERN DAY OLYMPICS__________________________ \n \n ")
print("Then 1,500 years later in 1892, a French educator named Baron Pierre de Coubertin\nbegan the Olympic revival movement. Baron de Coubertin's idea\nto reinstate the Olympic Games was presented to the audience at the international congress\nin Paris, 1894, and his proposal was unanimously approved. Two years later the unforgettable\nfirst modern Olympic Games were held in Athens, Greece, the homeland of the ancient Olympic Games.T\n \nThe five rings — the well-known symbol of the Olympic Games — were also created by Baron de Coubertin,\nto express the solidarity of the world's five continents.")

while True:
    print(" \n \n Enter values into different events of Tokyo Olympics and Paralympics 2020\n \n For Swimming-1 \n For Javelin-2 \n For High Jump-3 \n Exit-4")
    s= int(input(" "))
    if(s==1):
        s1=Swimming()
        s1=Swimming("Paralympics")
        continue
    elif(s==2):
        j1=Javelin()
        j1=Javelin("Paralympics")
        continue
    elif(s==3):
        h1=HighJump()
        h1=HighJump("Paralympics")
        continue
    elif(s==4):
        break
    else:
        print("Enter valid option")
        continue
# Out:
#  _______________________THE HISTORY OF OLYMPICS_________________________
#
#
# The roots of today’s Olympic Games date back to the ancient Olympic Games,
# held 2,800 years ago. Also known as the '''Olympiad''' the event
# took place in the Olympia region of ancient Greece. There are various
# pinions regarding its origins. It is said that the event was an athletic
# and artistic festival dedicated to the worship of the gods.
# But the ancient Olympic Games were hindered by numerous conflicts and finally
# came to an end in 393 AD.
#  ________________________MODERN DAY OLYMPICS__________________________
#
#
# Then 1,500 years later in 1892, a French educator named Baron Pierre de Coubertin
# began the Olympic revival movement. Baron de Coubertin's idea
# to reinstate the Olympic Games was presented to the audience at the international congress
# in Paris, 1894, and his proposal was unanimously approved. Two years later the unforgettable
# ...
