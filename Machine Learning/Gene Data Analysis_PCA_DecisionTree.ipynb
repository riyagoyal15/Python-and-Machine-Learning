# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:/Downloads/Test1_Dataset - Sheet1.csv")
df.head()
# Out:
#       T        V1        V2        V3        V4        V5        V6        V7  \
# 0   406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545 -2.537387
# 1   472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823  0.325574
# 2  4462 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788  0.562320
# 3  6986 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536 -3.496197
# 4  7519  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746  1.713445
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211  0.320198  0.044519
# 1 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966 -0.293803  0.279798
# 2 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726 -0.087330 -0.156114
# 3 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207 -0.053502  0.252405
# 4 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805 -1.632653  1.488901
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       1000 non-null   int64
#  1   V1      1000 non-null   float64
#  2   V2      1000 non-null   float64
#  3   V3      1000 non-null   float64
#  4   V4      1000 non-null   float64
#  5   V5      1000 non-null   float64
#  6   V6      1000 non-null   float64
#  7   V7      1000 non-null   float64
#  8   V8      1000 non-null   float64
#  9   V9      1000 non-null   float64
#  10  V10     1000 non-null   float64
#  11  V11     1000 non-null   float64
#  12  V12     1000 non-null   float64
#  13  V13     1000 non-null   float64
#  14  V14     1000 non-null   float64
#  15  V15     1000 non-null   float64
#  16  V16     1000 non-null   float64
#  17  V17     1000 non-null   float64
#  18  V18     1000 non-null   float64
#  19  V19     1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# T       0
# V1      0
# V2      0
# V3      0
# V4      0
# V5      0
# V6      0
# V7      0
# V8      0
# V9      0
# V10     0
# V11     0
# V12     0
# V13     0
# V14     0
# V15     0
# V16     0
# V17     0
# V18     0
# V19     0
# V20     0
# V21     0
# V22     0
# V23     0
# V24     0
# V25     0
# V26     0
# V27     0
# V28     0
# P      20
# C       0
# dtype: int64

# %%
P= df['P'].describe()
print('Mean P: {}'.format(P['mean']))

plt.figure(figsize = (10, 6))
sns.distplot(df['P'])
plt.title('P Distribution plot')
plt.axvline(P['mean'], linestyle = '-', color = "red")
# Out:
# Mean P: 96.83941836734687
# D:\ANACONDA\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We can see that it is right skewed. Hence we replace values with median

# %%
df["P"].fillna(df["P"].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# T      0
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# P      0
# C      0
# dtype: int64

# %% [markdown]
# Hence, we replaced null values with median values

# %%
df.describe()
# Out:
#                  T           V1           V2           V3           V4  \
# count    1000.0000  1000.000000  1000.000000  1000.000000  1000.000000
# mean    39818.2980    -2.423092     1.879156    -3.016093     2.423368
# std     52425.6199     5.375620     3.574000     6.404531     3.033820
# min         0.0000   -30.552380   -12.114213   -31.103685    -4.515824
# 25%       170.5000    -2.698354     0.083608    -5.041248     0.335999
# 50%       368.0000    -0.771744     0.940448    -0.273562     1.357754
# 75%     73595.7500     0.913013     2.710365     0.955399     4.106961
# max    170348.0000     2.132386    22.057729     3.772857    12.114672
#
#                 V5           V6           V7           V8           V9  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean     -1.536459    -0.559612    -2.686972     0.258223    -1.277408  ...
# std       4.175273     1.794608     5.826724     4.811274     2.257078  ...
# ...

# %%
fig, axs = plt.subplots(1, 1, figsize=(18, 14))
corr = df.corr()
sns.heatmap(corr, annot = True, linewidth=1)
# Out:
# <AxesSubplot:>

# %%
df['P'].plot(kind = 'hist') 
plt.title('P')
print(sns.boxplot(df["P"]))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# D:\ANACONDA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.drop(df[df['P'] >500].index , axis = 0 , inplace = True)

# %%
P= df['P'].describe()
print('Mean P: {}'.format(P['mean']))

plt.figure(figsize = (10, 6))
sns.distplot(df['P'])
plt.title('P Distribution plot')
plt.axvline(P['mean'], linestyle = '-', color = "red")
# Out:
# Mean P: 54.38026205450729
# D:\ANACONDA\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Function to plot histograms
def cc(df):
    nc = df.select_dtypes(include=['number']).columns.tolist()
    dataframe = df[nc]
    
    for i in range(0,len(nc),2):
        if len(nc) > i+1:
            plt.figure(figsize=(10,4))
            plt.subplot(121)
            sns.distplot(dataframe[nc[i]], kde=False)
            plt.subplot(122)            
            sns.distplot(dataframe[nc[i+1]], kde=False)
            plt.tight_layout()
            plt.show()

        else:
            sns.distplot(dataframe[nc[i]], kde=False)
cc(df)
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# These graph suggest that we should use on parametric approach

# %%
from scipy.stats.mstats import winsorize

# Function to treat outliers 
def treat_outliers(dataframe):
    cols = list(dataframe)
    for col in cols:
        if col in dataframe.select_dtypes(include=np.number).columns:
            dataframe[col] = winsorize(dataframe[col], limits=[0.05, 0.1],inclusive=(True, True))
    
    return dataframe

# %%
df['C'].value_counts()
sex = df['C'].value_counts()
f, ax = plt.subplots(figsize=(10,10))
chart1 = plt.pie(sex, labels = sex.index, colors = sns.color_palette("plasma"))
plt.title('Target Variable', fontsize=20)
plt.legend(['0', '1'])

# %% [markdown]
# We can see that our data is well-balanced

# %% [markdown]
# Before any further EDA, we would go for dimentionality reduction

# %%
X = df.iloc[:, 0:29].values
y = df.iloc[:, 30].values

# %%
from sklearn.preprocessing import StandardScaler

df = pd.DataFrame(X)
y_target = pd.DataFrame(y)
scalar = StandardScaler()

# %%
pca = PCA().fit(data_rescaled)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
from sklearn.decomposition import PCA
# Let's say, components = 2
pca = PCA(n_components = 15)
pca.fit(data_rescaled)
x_pca = pca.transform(data_rescaled)
print(x_pca.shape)
PCA_df = pd.DataFrame(x_pca)
PCA_df.head()
# Out:
# (954, 15)
#          0         1         2         3         4         5         6   \
# 0  0.050738 -0.218026 -0.524998 -0.219767  0.043123 -0.165373 -0.381746
# 1 -0.509453  0.070704  0.292475  0.905559  0.044395  1.220424  0.178201
# 2  2.149741 -0.960285 -0.137923  0.460198 -0.537829  1.082220  0.739119
# 3 -1.764969 -1.119580  0.028511 -2.880709  3.069108 -1.323857 -1.790427
# 4  1.457308 -1.857823 -0.010979 -2.549196  2.279695 -0.431972 -0.105647
#
#          7         8         9         10        11        12        13  \
# 0 -0.815525  0.441083 -0.717153 -0.225832 -0.243870  0.553466 -0.047449
# 1  1.642384 -0.143556  0.208072 -0.997229 -0.586762  1.261454  1.324025
# 2 -1.016440 -1.203760  1.153295 -0.759779 -0.917841 -0.564929  1.988944
# 3  1.582416 -0.409329  0.139543  1.006715 -0.665394 -0.467470  1.410916
# 4 -0.752159  1.483756  0.168139 -0.103903 -1.403582  0.509048  1.299877
#
#          14
# 0  0.183846
# 1 -0.187215
# 2 -0.221002
# 3  0.201273
# 4  0.381906

# %% [markdown]
# We see that almost 15 variables explain 95% of our variance and there is not much change after that. Hence we take 15 variables

# %%
pca.explained_variance_ratio_
# Out:
# array([0.3923044 , 0.10186735, 0.07490306, 0.05931297, 0.05428952,
#        0.03882391, 0.03562923, 0.03370862, 0.03010072, 0.02734644,
#        0.02524352, 0.02058243, 0.01781063, 0.01668268, 0.01333493])

# %%
from sklearn.model_selection import train_test_split as tts
X_train_2,X_test_2,y_train,y_test = tts(x_pca,y
,random_state=0
,stratify=y
)

# %%
from sklearn.model_selection import train_test_split as tts
X_train,X_test,y_train,y_test = tts(X,y
,random_state=0
,stratify=y
)

# %%
from sklearn.tree import DecisionTreeClassifier as DTC
model_1 = DTC().fit(X_train,y_train)
model_2 = DTC().fit(X_train_2,y_train)
score_1 = model_1.score(X_test,y_test)
score_2 = model_2.score(X_test_2,y_test)
print("score_2",{score_2})
# Out:
# score_2 {0.9581589958158996}

# %% [markdown]
# Hence, our model gives 95% accuracy with PCA and 15 variables.

# %%
#We will perform feature selection now on 15 variable dataset

from sklearn.feature_selection import mutual_info_classif as MIC #Mutual Inf
mi_score = MIC(x_pca,y)
print(mi_score)
# Out:
# [0.50940431 0.27823272 0.09960101 0.25949943 0.1600792  0.11390837
#  0.08933306 0.04633244 0.02437094 0.04092948 0.06587052 0.005898
#  0.01840341 0.08228186 0.07288804]

# %%
#selecting variables with entropy >0.1
import numpy as np
mi_score_selected_index = np.where(mi_score >0.1)[0]
X_3 = x_pca[:,mi_score_selected_index]
X_train_3,X_test_3,y_train,y_test = tts(
X_3,y
,random_state=0
,stratify=y
)

# %%
mi_score_selected_index = np.where(mi_score < 0.1)[0]
X_4 = x_pca[:,mi_score_selected_index]
X_train_4,X_test_4,y_train,y_test = tts(
X_4,y
,random_state=0
,stratify=y
)

# %%
model_3 = DTC().fit(X_train_3,y_train)
model_4 = DTC().fit(X_train_4,y_train)
score_3 = model_3.score(X_test_3,y_test)
score_4 = model_4.score(X_test_4,y_test)

print(f"score_3:{score_3}\n score_4:{score_4}")
# Out:
# score_3:0.9581589958158996
#  score_4:0.7656903765690377

# %% [markdown]
# Clearly, the model with >0.1 gives better accuracy

# %% [markdown]
# We finally have a model wih reduced number of variables using PCA and entropy based feature selection
