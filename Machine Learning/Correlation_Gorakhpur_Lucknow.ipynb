# %%
import pandas as pd

# %%
gorakhpur_urban = pd.read_excel('/content/gorakh_urban.xlsx')
gorakhpur_rural = pd.read_excel('/content/gorakh_rural.xlsx')
lucknow_rural = pd.read_excel("/content/lucknow_rural.xlsx")

# %%
df_both = pd.concat([gorakhpur_urban, gorakhpur_rural], ignore_index=True)

# %%
df_both
# Out:
#       Unnamed: 0  ...  medical facilty at work
# 0              0  ...                        Y
# 1              1  ...                        N
# 2              2  ...                        N
# 3              3  ...                        N
# 4              4  ...                        N
# ...          ...  ...                      ...
# 5558        5558  ...                        N
# 5559        5559  ...                        N
# 5560        5560  ...                        N
# 5561        5561  ...                        N
# 5562        5562  ...                        N
#
# [5563 rows x 100 columns]

# %%
lucknow_rural.head(15)
# Out:
#                           id   datetime  ... Loan Assets FI Financial Index Negative
# 0   5f7af6d6b0cac16c6db765ff 2020-10-05  ...              N                        Y
# 1   5f7afa20b0cac16c6db7660c 2020-10-05  ...              N                        Y
# 2   5f7afe717c43bd1cdc44a468 2020-10-05  ...              N                        Y
# 3   5f7afe7d9af8689af7741d44 2020-10-05  ...              N                        Y
# 4   5f7afeb07c43bd1cdc44a469 2020-10-05  ...              N                        Y
# 5   5f7afeb07c43bd1cdc44a46a 2020-10-05  ...              N                        Y
# 6   5f7afeb09af8689af7741d45 2020-10-05  ...              N                        Y
# 7   5f7afeb10eccb04d096600fa 2020-10-05  ...              N                        Y
# 8   5f7b002f0eccb04d096600fd 2020-10-05  ...              N                        N
# 9   5f7b00477c43bd1cdc44a46e 2020-10-05  ...              N                        N
# ...

# %%
df_new = pd.concat([df_both,lucknow_rural], ignore_index=True)

# %%
df_new
# Out:
#       Unnamed: 0  Column1  ...  Cluster_Code District_Code
# 0            0.0      1.0  ...           NaN           NaN
# 1            1.0      2.0  ...           NaN           NaN
# 2            2.0      3.0  ...           NaN           NaN
# 3            3.0      4.0  ...           NaN           NaN
# 4            4.0      5.0  ...           NaN           NaN
# ...          ...      ...  ...           ...           ...
# 6459         NaN      NaN  ...           NaN           NaN
# 6460         NaN      NaN  ...           NaN           NaN
# 6461         NaN      NaN  ...           NaN           NaN
# 6462         NaN      NaN  ...           NaN           NaN
# 6463         NaN      NaN  ...           NaN           NaN
#
# [6464 rows x 106 columns]

# %%
lucknow_rural.columns
# Out:
# Index(['id', 'datetime', 's_time', 'userid', 'survey_type', 'lat', 'long',
#        'age', 'gender', 'community', 'educ_qua', 'work_sector',
#        'work_sector_i', 'bonus', 'tot_mon_income_house', 'tot_mon_exp_house',
#        'tot_cumm_save_cih_bk', 'tot_cumm_saving_jewlry', 'fixed_asset_land',
#        'fixed_asset_house', 'fixed_asset_cattle', 'debt_to_bank',
#        'debt_to_contractors', 'debt_to_money_lender',
#        'migrated_to_current_place_6_month', 'type_migration',
#        'emp_status_before_migration', 'tot_emp_workplace',
#        'medical_faclity_workspace', 'work_effect_health',
#        'rest_room_woman_workplace', 'problems_in_behaviour_superiors',
#        'problems_in_policies_management',
#        'problems_in_nonredressal_grievances', 'problems_in_others',
#        'schemes_by_govt_emp_generation', 'schemes_by_govt_household',
#        'schemes_by_govt_agri_ins', 'schemes_by_govt_health_ins',
# ...

# %%
df_new.drop(['id','lat','long','Location code','Cluster_Code','District_Code'],axis=1)
# Out:
#       Unnamed: 0  ...  medical facilty at work
# 0            0.0  ...                        Y
# 1            1.0  ...                        N
# 2            2.0  ...                        N
# 3            3.0  ...                        N
# 4            4.0  ...                        N
# ...          ...  ...                      ...
# 6459         NaN  ...                      NaN
# 6460         NaN  ...                      NaN
# 6461         NaN  ...                      NaN
# 6462         NaN  ...                      NaN
# 6463         NaN  ...                      NaN
#
# [6464 rows x 100 columns]

# %%
df_new_2 = df_new[['age', 'gender', 'community', 'educ_qua', 'work_sector',
       'work_sector_i', 'bonus', 'tot_mon_income_house', 'tot_mon_exp_house',
       'tot_cumm_save_cih_bk', 'tot_cumm_saving_jewlry', 'fixed_asset_land',
       'fixed_asset_house', 'fixed_asset_cattle', 'debt_to_bank',
       'debt_to_contractors', 'debt_to_money_lender',
       'migrated_to_current_place_6_month', 'type_migration',
       'emp_status_before_migration', 'tot_emp_workplace',
       'medical_faclity_workspace', 'work_effect_health',
       'rest_room_woman_workplace', 'problems_in_behaviour_superiors',
       'problems_in_policies_management',
       'problems_in_nonredressal_grievances', 'problems_in_others',
       'schemes_by_govt_emp_generation', 'schemes_by_govt_household',
       'schemes_by_govt_agri_ins', 'schemes_by_govt_health_ins',
       'schemes_by_govt_other', 'below_poverty_line', 'health_status',
       'treat_location', 'quality_treatment', 'Location code', 'Cluster_Code',
       'District_Code', 'Monthly Income FI', 'BPL FI',
       'Income Expenses Savings FI', 'Loan Assets FI',
       'Financial Index Negative']]

# %%
df_new_2.drop(['Location code',	'Cluster_Code',	'District_Code'],axis=1)
# Out:
#        age  gender  ... Loan Assets FI Financial Index Negative
# 0     32.0  Female  ...              N                        Y
# 1     45.0    Male  ...              N                        Y
# 2     51.0  Female  ...              N                        Y
# 3     18.0    Male  ...              N                        Y
# 4     18.0  Female  ...              N                        Y
# ...    ...     ...  ...            ...                      ...
# 6459  33.0  Female  ...              N                        N
# 6460  39.0    Male  ...              N                        Y
# 6461  28.0  Female  ...              N                        Y
# 6462  38.0    Male  ...              N                        Y
# 6463  19.0    Male  ...              N                        Y
#
# [6464 rows x 42 columns]

# %%
for col in df_new_2:
    print(df_new_2[col]) 
    print(df_new_2[col].unique())
# Out:
# 0       32.0
# 1       45.0
# 2       51.0
# 3       18.0
# 4       18.0
#         ...
# 6459    33.0
# 6460    39.0
# 6461    28.0
# 6462    38.0
# 6463    19.0
# Name: age, Length: 6464, dtype: float64
# [ 32.  45.  51.  18.  38.  50.  24.  52.  29.  49.  25.  27.  80.  60.
#   65.  54.  19.  43.  75.  57.  30.  10.  41.  40.  nan  20.  34.  28.
#   44.  42.  37.  23.  35.  47.  73.  79.  55.  31.  70.  21.  36.  56.
#   46.  26.  33.  22.  63.  16.  15.  13.  69.  61.  17.  64.   8.  14.
#   71.  12.  68.  72.  39.  59.  85.  48.  11.   2.   6.   5.  53.   7.
#    4.  66.  62.  58.  74.   9.  67.  81.  83.   3.  76. 114.]
# 0       Female
# 1         Male
# 2       Female
# 3         Male
# 4       Female
#          ...
# 6459    Female
# 6460      Male
# 6461    Female
# 6462      Male
# 6463      Male
# Name: gender, Length: 6464, dtype: object
# ['Female' 'Male' nan 'Other']
# 0       OBC
# 1        SC
# 2        SC
# 3        SC
# 4        SC
#        ...
# 6459     SC
# ...

# %%
df_new_2.columns
# Out:
# Index(['age', 'gender', 'community', 'educ_qua', 'work_sector',
#        'work_sector_i', 'bonus', 'tot_mon_income_house', 'tot_mon_exp_house',
#        'tot_cumm_save_cih_bk', 'tot_cumm_saving_jewlry', 'fixed_asset_land',
#        'fixed_asset_house', 'fixed_asset_cattle', 'debt_to_bank',
#        'debt_to_contractors', 'debt_to_money_lender',
#        'migrated_to_current_place_6_month', 'type_migration',
#        'emp_status_before_migration', 'tot_emp_workplace',
#        'medical_faclity_workspace', 'work_effect_health',
#        'rest_room_woman_workplace', 'problems_in_behaviour_superiors',
#        'problems_in_policies_management',
#        'problems_in_nonredressal_grievances', 'problems_in_others',
#        'schemes_by_govt_emp_generation', 'schemes_by_govt_household',
#        'schemes_by_govt_agri_ins', 'schemes_by_govt_health_ins',
#        'schemes_by_govt_other', 'below_poverty_line', 'health_status',
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()

# %%
df_new_2[['schemes_by_govt_health_ins','schemes_by_govt_other'	,'below_poverty_line','health_status','quality_treatment','Monthly Income FI','BPL FI','Income Expenses Savings FI','Loan Assets FI','Financial Index Negative']] =  ord_enc.fit_transform(df_new_2[['schemes_by_govt_health_ins','schemes_by_govt_other'	,'below_poverty_line','health_status','quality_treatment','Monthly Income FI','BPL FI','Income Expenses Savings FI','Loan Assets FI','Financial Index Negative']])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
df_new_2
# Out:
#        age  gender  ... Loan Assets FI Financial Index Negative
# 0     32.0  Female  ...            0.0                      1.0
# 1     45.0    Male  ...            0.0                      1.0
# 2     51.0  Female  ...            0.0                      1.0
# 3     18.0    Male  ...            0.0                      1.0
# 4     18.0  Female  ...            0.0                      1.0
# ...    ...     ...  ...            ...                      ...
# 6459  33.0  Female  ...            0.0                      0.0
# 6460  39.0    Male  ...            0.0                      1.0
# 6461  28.0  Female  ...            0.0                      1.0
# 6462  38.0    Male  ...            0.0                      1.0
# 6463  19.0    Male  ...            0.0                      1.0
#
# [6464 rows x 42 columns]

# %%
 df_new_2[['problems_in_behaviour_superiors',
       'problems_in_policies_management',
       'problems_in_nonredressal_grievances', 'problems_in_others',
       'schemes_by_govt_emp_generation', 'schemes_by_govt_household',
       'schemes_by_govt_agri_ins']]=ord_enc.fit_transform(df_new_2[['problems_in_behaviour_superiors',
       'problems_in_policies_management',
       'problems_in_nonredressal_grievances', 'problems_in_others',
       'schemes_by_govt_emp_generation', 'schemes_by_govt_household',
       'schemes_by_govt_agri_ins']])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
df_new_2
# Out:
#        age  gender  ... Loan Assets FI Financial Index Negative
# 0     32.0  Female  ...            0.0                      1.0
# 1     45.0    Male  ...            0.0                      1.0
# 2     51.0  Female  ...            0.0                      1.0
# 3     18.0    Male  ...            0.0                      1.0
# 4     18.0  Female  ...            0.0                      1.0
# ...    ...     ...  ...            ...                      ...
# 6459  33.0  Female  ...            0.0                      0.0
# 6460  39.0    Male  ...            0.0                      1.0
# 6461  28.0  Female  ...            0.0                      1.0
# 6462  38.0    Male  ...            0.0                      1.0
# 6463  19.0    Male  ...            0.0                      1.0
#
# [6464 rows x 42 columns]

# %%
df_new_2[['fixed_asset_land',
       'fixed_asset_house', 'fixed_asset_cattle', 'debt_to_bank',
       'debt_to_contractors', 'debt_to_money_lender']]=ord_enc.fit_transform(df_new_2[['fixed_asset_land',
       'fixed_asset_house', 'fixed_asset_cattle', 'debt_to_bank',
       'debt_to_contractors', 'debt_to_money_lender']])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
df_new_2
# Out:
#        age  gender  ... Loan Assets FI Financial Index Negative
# 0     32.0  Female  ...            0.0                      1.0
# 1     45.0    Male  ...            0.0                      1.0
# 2     51.0  Female  ...            0.0                      1.0
# 3     18.0    Male  ...            0.0                      1.0
# 4     18.0  Female  ...            0.0                      1.0
# ...    ...     ...  ...            ...                      ...
# 6459  33.0  Female  ...            0.0                      0.0
# 6460  39.0    Male  ...            0.0                      1.0
# 6461  28.0  Female  ...            0.0                      1.0
# 6462  38.0    Male  ...            0.0                      1.0
# 6463  19.0    Male  ...            0.0                      1.0
#
# [6464 rows x 42 columns]

# %%
df_final = df_new_2[['fixed_asset_land',
       'fixed_asset_house', 'fixed_asset_cattle', 'debt_to_bank',
       'debt_to_contractors', 'debt_to_money_lender','problems_in_behaviour_superiors',
       'problems_in_policies_management',
       'problems_in_nonredressal_grievances', 'problems_in_others',
       'schemes_by_govt_emp_generation', 'schemes_by_govt_household',
       'schemes_by_govt_agri_ins','schemes_by_govt_health_ins','schemes_by_govt_other'	,'below_poverty_line','health_status','quality_treatment','Monthly Income FI','BPL FI','Income Expenses Savings FI','Loan Assets FI','Financial Index Negative']]

# %%
df_final.corr()
# Out:
#                                      fixed_asset_land  ...  Financial Index Negative
# fixed_asset_land                             1.000000  ...                  0.086783
# fixed_asset_house                           -0.700113  ...                 -0.054945
# fixed_asset_cattle                          -0.096594  ...                 -0.038881
# debt_to_bank                                 0.116902  ...                 -0.049098
# debt_to_contractors                         -0.038213  ...                  0.027881
# debt_to_money_lender                         0.042880  ...                  0.110111
# problems_in_behaviour_superiors              0.131470  ...                 -0.005631
# problems_in_policies_management              0.080585  ...                  0.050544
# problems_in_nonredressal_grievances         -0.050479  ...                  0.026372
# problems_in_others                          -0.031925  ...                  0.041234
# ...

# %%
sns.heatmap(df_final.corr(), cmap="YlGnBu")
