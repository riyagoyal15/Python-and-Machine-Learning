# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-146-8e765b7a5030> in <module>
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 import seaborn as sns
# ----> 6 import plotly.express as px
#       7 import plotly.graph_objects as go
#
# ModuleNotFoundError: No module named 'plotly'

# %%
#to read the csv file
df=pd.read_csv("D:/Downloads/basketball.csv")

# %%
df.head()
# Out:
#   League       Season           Stage                 Player Team  GP     MIN  \
# 0    NBA  2019 - 2020  Regular_Season           James Harden  HOU  68  2482.6
# 1    NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66  2473.7
# 2    NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70  2511.8
# 3    NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63  1916.9
# 4    NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60  2120.1
#
#    FGM   FGA  3PM  ...    birth_date  height  height_cm  weight  weight_kg  \
# 0  672  1514  299  ...  Aug 26, 1989  06-May        196     220        100
# 1  624  1349  270  ...  Jul 15, 1990  06-Mar        191     195         88
# 2  627  1283  141  ...  Oct 30, 1996  06-Jun        198     206         93
# 3  685  1238   89  ...   Dec 6, 1994  06-Nov        211     242        110
# 4  546  1249  205  ...  Sep 19, 1998  06-Feb        188     180         82
#
# ...

# %%
df.tail()
# Out:
#     League       Season     Stage            Player Team  GP    MIN  FGM  FGA  \
# 415    NBA  2019 - 2020  Playoffs     Wesley Iwundu  ORL   5   75.8    6   20
# 416    NBA  2019 - 2020  Playoffs      Semi Ojeleye  BOS  13  122.2    7   28
# 417    NBA  2019 - 2020  Playoffs        J.R. Smith  LAL  10   74.9    7   26
# 418    NBA  2019 - 2020  Playoffs      Juwan Morgan  UTA   7   86.5    3   12
# 419    NBA  2019 - 2020  Playoffs  Matisse Thybulle  PHI   4   75.3    3    7
#
#      3PM  ...    birth_date  height  height_cm  weight  weight_kg  \
# 415    4  ...  Dec 20, 1994  06-Jul        201     195         88
# 416    5  ...   Dec 5, 1994  06-Jul        201     241        109
# 417    6  ...   Sep 9, 1985  06-Jun        198     225        102
# 418    2  ...  Apr 17, 1997  06-Aug        203     232        105
# 419    1  ...   Mar 4, 1997  06-May        196     200         91
#
#        nationality                          high_school  draft_round  \
# ...

# %%
#to know number of columns and rows

df.shape
# Out:
# (420, 34)

# %%
#to see the number of unique values in Stage column

print(df['Stage'].nunique())
df['Stage'].unique()
# Out:
# 2
# array(['Regular_Season', 'Playoffs'], dtype=object)

# %%
#to count the number of players in each Stage
df.groupby('Stage').count()
# Out:
#                 League  Season  Player  Team   GP  MIN  FGM  FGA  3PM  3PA  \
# Stage
# Playoffs           140     140     140   140  140  140  140  140  140  140
# Regular_Season     280     280     280   280  280  280  280  280  280  280
#
#                 ...  birth_date  height  height_cm  weight  weight_kg  \
# Stage           ...
# Playoffs        ...         140     140        140     140        140
# Regular_Season  ...         280     280        280     280        280
#
#                 nationality  high_school  draft_round  draft_pick  draft_team
# Stage
# Playoffs                140          123          111         111         111
# Regular_Season          280          245          245         245         245
#
# [2 rows x 33 columns]

# %%
# to know the nuber of null values in each column

df.isnull().sum()
# Out:
# League          0
# Season          0
# Stage           0
# Player          0
# Team            0
# GP              0
# MIN             0
# FGM             0
# FGA             0
# 3PM             0
# 3PA             0
# FTM             0
# FTA             0
# TOV             0
# PF              0
# ORB             0
# DRB             0
# REB             0
# AST             0
# STL             0
# BLK             0
# PTS             0
# birth_year      0
# birth_month     0
# birth_date      0
# height          0
# height_cm       0
# weight          0
# weight_kg       0
# nationality     0
# high_school    52
# draft_round    64
# draft_pick     64
# draft_team     64
# dtype: int64

# %%
#to count the number of players in each Stage

print(len(df[df['Stage'] == 'Playoffs']))
len(df[df['Stage'] == 'Regular_Season'])
# Out:
# 140
# 280

# %%
#to get basic statistics for the players by making a smaller data frame

df_small=df[["Stage","Player","Team",
"GP","MIN","FGM","FGA","3PM","3PA","FTM","FTA","TOV","PF","ORB","DRB","REB","AST","STL","BLK","PTS"]]
print(df_small)

df_small.describe()
# Out:
#               Stage                 Player Team  GP     MIN  FGM   FGA  3PM  \
# 0    Regular_Season           James Harden  HOU  68  2482.6  672  1514  299
# 1    Regular_Season         Damian Lillard  POR  66  2473.7  624  1349  270
# 2    Regular_Season           Devin Booker  PHX  70  2511.8  627  1283  141
# 3    Regular_Season  Giannis Antetokounmpo  MIL  63  1916.9  685  1238   89
# 4    Regular_Season             Trae Young  ATL  60  2120.1  546  1249  205
# ..              ...                    ...  ...  ..     ...  ...   ...  ...
# 415        Playoffs          Wesley Iwundu  ORL   5    75.8    6    20    4
# 416        Playoffs           Semi Ojeleye  BOS  13   122.2    7    28    5
# 417        Playoffs             J.R. Smith  LAL  10    74.9    7    26    6
# 418        Playoffs           Juwan Morgan  UTA   7    86.5    3    12    2
# 419        Playoffs       Matisse Thybulle  PHI   4    75.3    3     7    1
#
# ...

# %%
# No. of teams in NBA

print('The various teams of NBA are : \n\n', df['Team'].unique())
print("\n \n The total number of teams are :", len(df['Team'].unique()))
# Out:
# The various teams of NBA are :
#
#  ['HOU' 'POR' 'PHX' 'MIL' 'ATL' 'DAL' 'WAS' 'LAL' 'UTA' 'BOS' 'LAC' 'CHI'
#  'SAS' 'NOP' 'DEN' 'PHI' 'SAC' 'TOR' 'CLE' 'OKC' 'IND' 'BRK' 'NYK' 'ORL'
#  'MEM' 'GSW' 'MIA' 'CHA' 'MIN' 'DET']
#
#
#  The total number of teams are : 30

# %%
sns.displot(data=df, x=df["weight_kg"], col=df["Stage"], kde=True)

# %%
sns.displot(data=df, x=df["height_cm"], col=df["Stage"],kde=True)

# %%
# to find the distribution of point per game by each team

df.plot('Team', 'GP', kind='scatter',figsize=(20,10)
# Out:
# <AxesSubplot:xlabel='Team', ylabel='GP'>

# %%
small_df=df[["GP","draft_pick","weight_kg","height_cm"]]

plt.figure(figsize=(15,8))
sns.heatmap(small_df.corr(),annot=True, linewidths=.2,fmt=".2f",)
plt.show()

# %%
df.groupby("high_school").count()
# Out:
#                                     League  Season  Stage  Player  Team  GP  \
# high_school
# A&M Consolidated High School             2       2      2       2     2   2
# APEX Academy                             4       4      4       4     4   4
# Alliance Leadership Middle Academy       1       1      1       1     1   1
# Ames High School                         2       2      2       2     2   2
# Apple Valley High School                 1       1      1       1     1   1
# ...                                    ...     ...    ...     ...   ...  ..
# Whitnall High School                     2       2      2       2     2   2
# William Howard Taft High School          1       1      1       1     1   1
# Winter Park High School                  2       2      2       2     2   2
# Word of God Christian Academy            2       2      2       2     2   2
# Yates High School                        1       1      1       1     1   1
#
# ...

# %%
data = df.groupby(["Team"])["GP"].sum().sort_values(ascending=False)

plt.figure(figsize=(15,8))
sns.barplot(y=data.index,x=data,orient="h")
plt.title("Scores per team")
plt.xlabel("Total pointd")
plt.ylabel("Teams")
plt.show()

# %%
df_maxpoints=df.sort_values('FGM',ascending="True")
df_maxpoints=df_maxpoints[410:420]


sns.barplot(
    y =  list(df_maxpoints['Player']),
    x = list(df_maxpoints['FGM']))
# Out:
# <AxesSubplot:>
